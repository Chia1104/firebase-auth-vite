// %%
'use strict';

fs = require('fs');
assert = require('assert');
// dotenv = require('dotenv');
`${os.platform()};${process.cwd()}`
// Out:
// 'win32;c:\\m\\runpix\\functions'

// %% [markdown]
// # EXIF

// %%
exifReader=require('../functions/node_modules/exif-reader');
sharp = require('sharp');
// Out:
// [Function: Sharp] {
//   align: { left: 'low', center: 'centre', centre: 'centre', right: 'high' },
//   gravity: {
//     center: 0,
//     centre: 0,
//     north: 1,
//     east: 2,
//     south: 3,
//     west: 4,
//     northeast: 5,
//     southeast: 6,
//     southwest: 7,
//     northwest: 8
//   },
//   strategy: { entropy: 16, attention: 17 },
//   kernel: {
//     nearest: 'nearest',
//     cubic: 'cubic',
//     mitchell: 'mitchell',
//     lanczos2: 'lanczos2',
//     lanczos3: 'lanczos3'
//   },
//   fit: {
//     contain: 'contain',
//     cover: 'cover',
//     fill: 'fill',
//     inside: 'inside',
//     outside: 'outside'
//   },
//   position: {
//     top: 1,
//     right: 2,
//     bottom: 3,
//     left: 4,
//     'right top': 5,
//     'right bottom': 6,
//     'left bottom': 7,
//     'left top': 8
//   },
//   blend: {
//     clear: 'clear',
//     source: 'source',
//     over: 'over',
//     in: 'in',
//     out: 'out',
//     atop: 'atop',
// ...

// %%
img=sharp("C:\\Users\\AvinashMane\\Downloads\\20221224_143343.jpg")
// icc = require('icc');
// Out:
// Sharp {
//   _readableState: ReadableState {
//     objectMode: false,
//     highWaterMark: 16384,
//     buffer: BufferList { head: null, tail: null, length: 0 },
//     length: 0,
//     pipes: [],
//     flowing: null,
//     ended: false,
//     endEmitted: false,
//     reading: false,
//     constructed: true,
//     sync: true,
//     needReadable: false,
//     emittedReadable: false,
//     readableListening: false,
//     resumeScheduled: false,
//     errorEmitted: false,
//     emitClose: true,
//     autoDestroy: true,
//     destroyed: false,
//     errored: null,
//     closed: false,
//     closeEmitted: false,
//     defaultEncoding: 'utf8',
//     awaitDrainWriters: null,
//     multiAwaitDrain: false,
//     readingMore: false,
//     dataEmitted: false,
//     decoder: null,
//     encoding: null,
//     [Symbol(kPaused)]: null
//   },
//   _events: [Object: null prototype] {},
//   _eventsCount: 0,
//   _maxListeners: undefined,
// ...

// %%
// let m
img.metadata().then(x=>m=x)
// Out:
// Promise { <pending> }

// %%
m
// Out:
// evalmachine.<anonymous>:1
// m
// ^
//
// ReferenceError: m is not defined
//     at evalmachine.<anonymous>:1:1
//     at Script.runInThisContext (node:vm:129:12)
//     at Object.runInThisContext (node:vm:313:38)
//     at run ([eval]:1020:15)
//     at onRunRequest ([eval]:864:18)
//     at onMessage ([eval]:828:13)
//     at process.emit (node:events:513:28)
//     at emit (node:internal/child_process:937:14)
//     at process.processTicksAndRejections (node:internal/process/task_queues:83:21)

// %%
Object.assign(m,exifReader(m.exif))
// Out:
// evalmachine.<anonymous>:1
// Object.assign(m,exifReader(m.exif))
//               ^
//
// ReferenceError: m is not defined
//     at evalmachine.<anonymous>:1:15
//     at Script.runInThisContext (node:vm:129:12)
//     at Object.runInThisContext (node:vm:313:38)
//     at run ([eval]:1020:15)
//     at onRunRequest ([eval]:864:18)
//     at onMessage ([eval]:828:13)
//     at process.emit (node:events:513:28)
//     at emit (node:internal/child_process:937:14)
//     at process.processTicksAndRejections (node:internal/process/task_queues:83:21)

// %%
exifRdr.load((img.toBuffer()))
// Out:
// evalmachine.<anonymous>:1
// exifRdr.load((img.toBuffer()))
// ^
//
// ReferenceError: exifRdr is not defined
//     at evalmachine.<anonymous>:1:1
//     at Script.runInThisContext (node:vm:129:12)
//     at Object.runInThisContext (node:vm:313:38)
//     at run ([eval]:1020:15)
//     at onRunRequest ([eval]:864:18)
//     at onMessage ([eval]:828:13)
//     at process.emit (node:events:513:28)
//     at emit (node:internal/child_process:937:14)
//     at process.processTicksAndRejections (node:internal/process/task_queues:83:21)

// %% [markdown]
// # Functions

// %% [markdown]
// // Firebase setup
// // const functions = require('firebase-functions');
// const admin = require('firebase-admin');
//
// // admin.initializeApp();

// %% [markdown]
// let sa = require('/i/auth/run-pix-092258e3cb1b.json');

// %% [markdown]
// admin.initializeApp({
//   credential: admin.credential.cert(sa)
// });

// %%
let fstore = admin.firestore();

// %%
races=fstore.collection('races')
// Out:
// CollectionReference {
//   _firestore: Firestore {
//     _settings: {
//       credentials: [Object],
//       projectId: 'run-pix',
//       firebaseVersion: '11.4.1',
//       preferRest: undefined,
//       databaseId: '(default)',
//       libName: 'gccl',
//       libVersion: '6.4.2 fire/11.4.1',
//       toJson: [Function (anonymous)]
//     },
//     _settingsFrozen: true,
//     _serializer: Serializer {
//       createReference: [Function (anonymous)],
//       createInteger: [Function (anonymous)],
//       allowUndefined: false
//     },
//     _projectId: 'run-pix',
//     _databaseId: '(default)',
//     registeredListenersCount: 0,
//     bulkWritersCount: 0,
//     _backoffSettings: { initialDelayMs: 100, maxDelayMs: 60000, backoffFactor: 1.3 },
//     _clientPool: ClientPool {
//       concurrentOperationLimit: 100,
//       maxIdleClients: 1,
//       clientFactory: [Function (anonymous)],
//       clientDestructor: [Function (anonymous)],
// ...

// %%
races.doc('test').collection('readings').get().then()
// Out:
// Promise { <pending> }

// %%
fstore.collection('races').doc('test').collection('readings').doc('timestamp-bib').set({a:1,b:3}).then(console.log)
// Out:
// Promise { <pending> }
// WriteResult {
//   _writeTime: Timestamp { _seconds: 1675780089, _nanoseconds: 894385000 }
// }

// %%
// Out:
// Promise { <pending> }
// WriteResult {
//   _writeTime: Timestamp { _seconds: 1675782407, _nanoseconds: 425509000 }
// }

// %%
function printData(snap) {
    if (snap instanceof Array ) {
        return snap.forEach((d,i)=>{ let k=d['id'];
                            console.log( { k : d.data() })});
    } else {
        return snap.exists? snap.data() : 'missing'
    }
}

// %%
fstore.collection('races').doc('test').collection('readings').get().then(x=>printData(x))
// Out:
// Promise { <pending> }

// %%
fstore.collection('races').doc('test').collection('readings').get().then(prda);
// Out:
// Promise { <pending> }
// 20221012123434-bib  =>  { tttt: 1 }
// FfUz4JiS7Hk43BBNnbg3  =>  { b: 3, a: 1 }
// Vi2UEmy6sAYPEsYB0WG6  =>  { b: 3, a: 1 }
// gsKUatJoeMeIhOfeVtp3  =>  { a: 1, b: 3 }
// timestamp-bib  =>  { a: 1, b: 3 }

// %%
fstore.collection('races').doc('test1').get().then(printData)
// Out:
// Promise { <pending> }
// { Date: '2023-01-02T12:12:12', Location: 'PT', Name: 'test Race' }

// %%
prda=(querySnapshot) => {
    if (querySnapshot instanceof Array)
    querySnapshot.forEach((doc) => {
        console.log(doc.id, " => ", doc.data());
    });
}
// Out:
// [Function: prda]

// %%
yaml=require('yaml')
// Out:
// {
//   createNode: [Function: createNode],
//   defaultOptions: {
//     anchorPrefix: 'a',
//     customTags: null,
//     indent: 2,
//     indentSeq: true,
//     keepCstNodes: false,
//     keepNodeTypes: true,
//     keepBlobsInJSON: true,
//     mapAsMap: false,
//     maxAliasCount: 100,
//     prettyErrors: false,
//     simpleKeys: false,
//     version: '1.2'
//   },
//   Document: [class Document extends Document],
//   parse: [Function: parse],
//   parseAllDocuments: [Function: parseAllDocuments],
//   parseCST: [Function: parse],
//   parseDocument: [Function: parseDocument],
//   scalarOptions: {
//     binary: [Getter/Setter],
//     bool: [Getter/Setter],
//     int: [Getter/Setter],
//     null: [Getter/Setter],
//     str: [Getter/Setter]
//   },
//   stringify: [Function: stringify]
// }

// %%
yaml.parse(`path:
    # ends with \\
    # input: C:\Users\AvinashMane\Box\SolRep\input
    input: C:\Users\AvinashMane\Box\sah_operation_reporting\input
    template: C:\m\pyrep\Status Template.pptx
    GIC_pipeline: C:\Users\AvinashMane\Box\GIC CBDS Collab\pipeline

        
fieldMap:
    # oldField: newField
    'Opp No': 'OppNo'
    'Opportunity Number': 'OppNo'
    'Project Name': 'Opp_Name'
    'Client Name': 'Customer'
    'Cust Name': 'Customer'
    'Opportunity Status (ESA)': 'ESAStatus'
    'Sales Connect Sales Stage': 'ESAStatus'
    'Owner User Name': 'OppOwner'
    'OPPORTUNITY OWNER': 'OppOwner'
    'Ext TCV mUSD': 'TCV'
    'ESA - Full Scope GBS TCV ($M) = CS+AMS+GPS': 'TCV'
    'Solutioning Status (SWB)': "SWBStatus"
    'Solutioning Status (SSDB, SWB)': "SWBStatus"
    'Solutioning Status (SSDB SWB)': "SWBStatus"
    'GBSPRACTICEDESCRIPTION': 'Service_Area'
    # 'Primary Offering Area (as reported)': 'Service_Area'
    # 'Primary Service Line (as reported)': 'Service_Line'
    # 'Offering Area (as reported)': 'Service_Area_Rep'
    # 'Service Line (as reported)': 'Service_Line'
    # 'Primary Offering Area (as recorded)': 'Service_Area'
    'GBS Sector': 'Sector'
    'GBS Industry': 'Industry'
    'Solution Manager': "SM"
    'Solution Manager ': 'SM'
    'Senior Solution Manager': "SSM"
    'Other Senior Solution Manager(s)': 'OSSM'
    'Other Solution Manager(s)': 'OSM'
    'Other Solution Manager': 'OSM'
    'Geo/IOT': 'Geo'
    # 'New Geo':'Geo'
    'Region/IMT': 'Region'
    'Market': 'Region'
    'Dec Date': 'Dec_Dt'
    'Decision date (ESA)': 'Dec_Dt'
    'Decision Quarter': 'Dec_Qtr'
    'SMR Received date': 'SMR_Dt'
    'SM ASSIGNED DATE': 'Assgn_Dt'
    'Proposal Due Date': 'Prop_Dt'
    'DB2 Date': 'DB2_Dt'
    'Opp Create Date': 'Opp_Dt'
    'Indicative/WF Type Name': 'WF'
    'WF Type Name': 'WF'
    'Solution Excellence Release Date': 'Exc_Dt'
    # 'UT L30 Description': 'Prod_Cat_Description'
    'Deal Size(ESA)': 'Deal_Size'
    'Senior Solution Consultant': SSM
    ' Senior Solution Consultant': SSM
    'Solution Consultant': SM
    'Other Senior Solution Consultants': OSSM
    'Other Solution Consultants': OSM
    'Other Senior Solution Consultant(s)': OSSM
    Other Solution Consultant(s): OSM
    Service Area: Portfolio

valueMap:
    field:
        old: new
    Geo:
        North America: NA
        Americas: AM
        Europe: EU
        Japan: JP
        Middle East & Africa: MEA
        Greater China Group: GCG
        Asia Pacific: AP
        Latin America: LA
    Region:
        US: US
        UK and Ireland: UKI
        Japan: JP
        DACH: DACH
        Middle East and Africa: MEA
        Greater China: GCG
        SPGI: SPGI
        Nordic: Nordic
        Central and Eastern Europe: CEE
        India-South Asia: ISA
        Australia-New Zealand: ANZ
        Brazil: BRA
        Italy: ITA
        Canada: CAB
        BeNeLux: BeNeLux
        Korea: Korea
        France: France
        Asean: ASEAN
        SSA: SSA
        Mexico: Mexico
        Aus./New Zealand: ANZ
        Greater China Group: GCG
    Industry:
        Healthcare: HC
        Banking: BAN
        Electronics: ELE
        Chemicals & Petroleum: C&P
        Wholesale Distribution & Services: WHS
        Industrial Products: Ind
        Energy & Utilities: E&U
        Insurance: INS
        Consumer Products: CPG
        Finance Markets: FIN
        Government: GOV
        Telecommunications: Telco
        Automotive: Auto
        Travel & Transportation: T&T
        Unknown: _
        Retail: Ret
        Professional Services: Prof
        Media & Entertainment: M&E
        Life Sciences: LS
        Education: EDU
        Aerospace & Defense: A&D
    Service_Area:
        'Cognitive & Analytics (CBDS)': 'Cognitive & Analytics'
        'Cognitive and Analytics': 'Cognitive & Analytics'
        'Data Platform Services (CBDS)': 'Data Platform Services'
        'Watson Health & Curam (CBDS)': 'Cognitive & Analytics'
        'Watson IoT & Industry (4.0)': 'Intelligent Connected Operations'
        'Watson IoT & Industry 4.0 (CBDS)': 'Intelligent Connected Operations'
    Service_Line:
      Customer Transformation: CT
      Data & Tech Transformation: DTT
      Data & Technology Transformation: DTT
      Finance & Supply Chain Transformation: FSCT
      Hybrid Cloud Management: HCM
      Hybrid Cloud Security: SEC
      Hybrid Cloud Transformation: HCT
      Industry Transformation Units: ITU
      Talent Transformation: TT
      Industry Transformation: ITU
      Next Generation Enterprise Applications: NGEA
      Cognitive Process Services (BPO): CPS
    ESAStatus:
      Engage: 04-Engage
      Qualify: 05-Qualify
      Design: 05-Design
      Propose: 05-Propose
      Negotiate: 06-Negotiate
      Closing: 06-Closing
      Closed Won: 08-Won
      Closed Lost: 11-Lost
      Won: 08-Won
      Lost: 11-Lost
`)
// Out:
// {
//   path: {
//     input: 'C:UsersAvinashManeBoxsah_operation_reportinginput',
//     template: 'C:mpyrepStatus Template.pptx',
//     GIC_pipeline: 'C:UsersAvinashManeBoxGIC CBDS Collabpipeline'
//   },
//   fieldMap: {
//     'Opp No': 'OppNo',
//     'Opportunity Number': 'OppNo',
//     'Project Name': 'Opp_Name',
//     'Client Name': 'Customer',
//     'Cust Name': 'Customer',
//     'Opportunity Status (ESA)': 'ESAStatus',
//     'Sales Connect Sales Stage': 'ESAStatus',
//     'Owner User Name': 'OppOwner',
//     'OPPORTUNITY OWNER': 'OppOwner',
//     'Ext TCV mUSD': 'TCV',
//     'ESA - Full Scope GBS TCV ($M) = CS+AMS+GPS': 'TCV',
//     'Solutioning Status (SWB)': 'SWBStatus',
//     'Solutioning Status (SSDB, SWB)': 'SWBStatus',
//     'Solutioning Status (SSDB SWB)': 'SWBStatus',
//     GBSPRACTICEDESCRIPTION: 'Service_Area',
//     'GBS Sector': 'Sector',
//     'GBS Industry': 'Industry',
//     'Solution Manager': 'SM',
//     'Solution Manager ': 'SM',
// ...
